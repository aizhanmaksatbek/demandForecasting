# %% [markdown]
# # Packages

# %%
import pandas as pd
import wandb
# Out:
# /Users/aizhanm/Desktop/UM-4/demandForecasting/venv_demand/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /Users/aizhanm/Desktop/UM-4/demandForecasting/venv_demand/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %% [markdown]
# # Weights and Biases

# %%
def log_dataset_to_wandb(dataset_name, file_path):
    """
    Logs a dataset file to Weights and Biases as an artifact.
    Args:
        dataset_name (str): Name of the dataset artifact to create in Weights and Biases.
        file_path (str): Path to the local dataset file.
    """
    WndbSwitch = False
    if not WndbSwitch:
        return
    run = wandb.init(project="GNNDemandForecasting", job_type="dataset-creation")

    # Create a new artifact for a dataset
    artifact_log = wandb.Artifact(dataset_name, type='dataset')
    artifact_log.add_file(file_path)

    run.log_artifact(artifact_log)

    wandb.finish()

# %% [markdown]
# # Merge Files

# %%
holiday_events_path = "../source_files/holidays_events.csv"
oil_path = "../source_files/oil.csv"
stores_path = "../source_files/stores.csv"
test_path = "../source_files/test.csv"
train_path = "../source_files/train.csv"

# %%
holiday_events_df = pd.read_csv(holiday_events_path)
holiday_events_df = holiday_events_df.rename(columns={'type': 'day_type'})
holiday_events_df = holiday_events_df.rename(columns={'locale': 'day_locale'})
holiday_events_df = holiday_events_df.rename(columns={'locale_name': 'day_locale_name'})
holiday_events_df = holiday_events_df.rename(columns={'description': 'day_description'})
holiday_events_df = holiday_events_df.rename(columns={'transferred': 'day_transferred'})

holiday_events_df.head()
# Out:
#          date day_type day_locale day_locale_name  \
# 0  2012-03-02  Holiday      Local           Manta
# 1  2012-04-01  Holiday   Regional        Cotopaxi
# 2  2012-04-12  Holiday      Local          Cuenca
# 3  2012-04-14  Holiday      Local        Libertad
# 4  2012-04-21  Holiday      Local        Riobamba
#
#                  day_description  day_transferred
# 0             Fundacion de Manta            False
# 1  Provincializacion de Cotopaxi            False
# 2            Fundacion de Cuenca            False
# 3      Cantonizacion de Libertad            False
# 4      Cantonizacion de Riobamba            False

# %%
oil_df = pd.read_csv(oil_path)
oil_df = oil_df.rename(columns={'dcoilwtico': 'oil_price'})

oil_df.head()
# Out:
#          date  oil_price
# 0  2013-01-01        NaN
# 1  2013-01-02      93.14
# 2  2013-01-03      92.97
# 3  2013-01-04      93.12
# 4  2013-01-07      93.20

# %%
stores_df = pd.read_csv(stores_path)
stores_df = stores_df.rename(columns={'city': 'store_city'})
stores_df = stores_df.rename(columns={'state': 'store_state'})
stores_df = stores_df.rename(columns={'type': 'store_type'})
stores_df = stores_df.rename(columns={'cluster': 'store_cluster'})

stores_df.head()
# Out:
#    store_nbr     store_city                     store_state store_type  \
# 0          1          Quito                       Pichincha          D
# 1          2          Quito                       Pichincha          D
# 2          3          Quito                       Pichincha          D
# 3          4          Quito                       Pichincha          D
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas          D
#
#    store_cluster
# 0             13
# 1             13
# 2              8
# 3              9
# 4              4

# %%
test_df = pd.read_csv(test_path)
test_df.head()
# Out:
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
train_df = pd.read_csv(train_path)
train_df
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 3000883            0
# 3000884            1
# 3000885          148
# 3000886            8
# 3000887            0
#
# [3000888 rows x 6 columns]

# %%
def merge_dfs(df):
    df = df.merge(holiday_events_df, how='left', on='date')
    df = df.merge(oil_df, how='left', on='date')
    df = df.merge(stores_df, how='left', on='store_nbr')
    return df

# %%
train_merged = merge_dfs(train_df)
train_merged.to_csv("../processed_files/train_merged.csv", index=False)
# log_dataset_to_wandb("train_merged", "../processed_files/train_merged.csv")
train_merged.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion day_type  \
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  Holiday
# 1   1  2013-01-01          1   BABY CARE    0.0            0  Holiday
# 2   2  2013-01-01          1      BEAUTY    0.0            0  Holiday
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  Holiday
# 4   4  2013-01-01          1       BOOKS    0.0            0  Holiday
#
#   day_locale day_locale_name     day_description day_transferred  oil_price  \
# 0   National         Ecuador  Primer dia del ano           False        NaN
# 1   National         Ecuador  Primer dia del ano           False        NaN
# 2   National         Ecuador  Primer dia del ano           False        NaN
# 3   National         Ecuador  Primer dia del ano           False        NaN
# 4   National         Ecuador  Primer dia del ano           False        NaN
#
#   store_city store_state store_type  store_cluster
# 0      Quito   Pichincha          D             13
# 1      Quito   Pichincha          D             13
# 2      Quito   Pichincha          D             13
# 3      Quito   Pichincha          D             13
# 4      Quito   Pichincha          D             13

# %%
test_merged = merge_dfs(test_df)
test_merged.to_csv("../processed_files/test_merged.csv", index=False)
# log_dataset_to_wandb("test_merged", "../processed_files/test_merged.csv")
test_merged.head()
# Out:
#         id        date  store_nbr      family  onpromotion day_type  \
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0      NaN
# 1  3000889  2017-08-16          1   BABY CARE            0      NaN
# 2  3000890  2017-08-16          1      BEAUTY            2      NaN
# 3  3000891  2017-08-16          1   BEVERAGES           20      NaN
# 4  3000892  2017-08-16          1       BOOKS            0      NaN
#
#   day_locale day_locale_name day_description day_transferred  oil_price  \
# 0        NaN             NaN             NaN             NaN       46.8
# 1        NaN             NaN             NaN             NaN       46.8
# 2        NaN             NaN             NaN             NaN       46.8
# 3        NaN             NaN             NaN             NaN       46.8
# 4        NaN             NaN             NaN             NaN       46.8
#
#   store_city store_state store_type  store_cluster
# 0      Quito   Pichincha          D             13
# 1      Quito   Pichincha          D             13
# 2      Quito   Pichincha          D             13
# 3      Quito   Pichincha          D             13
# 4      Quito   Pichincha          D             13

# %% [markdown]
# # Preprocess
# - Remove nan

# %% [markdown]
# ## Impute NaN

# %%
train_merged.dropna(inplace=True)
train_merged.to_csv("../processed_files/train_merged.csv", index=False)
log_dataset_to_wandb("train_merged", "../processed_files/train_merged.csv")
train_merged
# Out:
#               id        date  store_nbr                      family     sales  \
# 73062      73062  2013-02-11          1                  AUTOMOTIVE     0.000
# 73063      73063  2013-02-11          1                   BABY CARE     0.000
# 73064      73064  2013-02-11          1                      BEAUTY     0.000
# 73065      73065  2013-02-11          1                   BEVERAGES   172.000
# 73066      73066  2013-02-11          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3054343  3000883  2017-08-15          9                     POULTRY   438.133
# 3054344  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3054345  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3054346  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3054347  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion day_type day_locale day_locale_name  \
# 73062              0  Holiday   National         Ecuador
# 73063              0  Holiday   National         Ecuador
# 73064              0  Holiday   National         Ecuador
# 73065              0  Holiday   National         Ecuador
# 73066              0  Holiday   National         Ecuador
# ...              ...      ...        ...             ...
# 3054343            0  Holiday      Local        Riobamba
# 3054344            1  Holiday      Local        Riobamba
# 3054345          148  Holiday      Local        Riobamba
# 3054346            8  Holiday      Local        Riobamba
# 3054347            0  Holiday      Local        Riobamba
#
#                day_description day_transferred  oil_price store_city  \
# 73062                 Carnaval           False      97.01      Quito
# 73063                 Carnaval           False      97.01      Quito
# 73064                 Carnaval           False      97.01      Quito
# 73065                 Carnaval           False      97.01      Quito
# 73066                 Carnaval           False      97.01      Quito
# ...                        ...             ...        ...        ...
# 3054343  Fundacion de Riobamba           False      47.57      Quito
# 3054344  Fundacion de Riobamba           False      47.57      Quito
# 3054345  Fundacion de Riobamba           False      47.57      Quito
# 3054346  Fundacion de Riobamba           False      47.57      Quito
# 3054347  Fundacion de Riobamba           False      47.57      Quito
#
#         store_state store_type  store_cluster
# 73062     Pichincha          D             13
# 73063     Pichincha          D             13
# 73064     Pichincha          D             13
# 73065     Pichincha          D             13
# 73066     Pichincha          D             13
# ...             ...        ...            ...
# 3054343   Pichincha          B              6
# 3054344   Pichincha          B              6
# 3054345   Pichincha          B              6
# 3054346   Pichincha          B              6
# 3054347   Pichincha          B              6
#
# [322542 rows x 16 columns]

# %%
test_merged.dropna(inplace=True)
test_merged.to_csv("../processed_files/test_merged.csv", index=False)
log_dataset_to_wandb("test_merged", "../processed_files/test_merged.csv")
test_merged
# Out:
#             id        date  store_nbr                      family  \
# 14256  3015144  2017-08-24          1                  AUTOMOTIVE
# 14257  3015145  2017-08-24          1                   BABY CARE
# 14258  3015146  2017-08-24          1                      BEAUTY
# 14259  3015147  2017-08-24          1                   BEVERAGES
# 14260  3015148  2017-08-24          1                       BOOKS
# ...        ...         ...        ...                         ...
# 16033  3016921  2017-08-24          9                     POULTRY
# 16034  3016922  2017-08-24          9              PREPARED FOODS
# 16035  3016923  2017-08-24          9                     PRODUCE
# 16036  3016924  2017-08-24          9  SCHOOL AND OFFICE SUPPLIES
# 16037  3016925  2017-08-24          9                     SEAFOOD
#
#        onpromotion day_type day_locale day_locale_name      day_description  \
# 14256            0  Holiday      Local          Ambato  Fundacion de Ambato
# 14257            0  Holiday      Local          Ambato  Fundacion de Ambato
# 14258            0  Holiday      Local          Ambato  Fundacion de Ambato
# 14259           26  Holiday      Local          Ambato  Fundacion de Ambato
# 14260            0  Holiday      Local          Ambato  Fundacion de Ambato
# ...            ...      ...        ...             ...                  ...
# 16033            0  Holiday      Local          Ambato  Fundacion de Ambato
# 16034            0  Holiday      Local          Ambato  Fundacion de Ambato
# 16035            3  Holiday      Local          Ambato  Fundacion de Ambato
# 16036            9  Holiday      Local          Ambato  Fundacion de Ambato
# 16037            0  Holiday      Local          Ambato  Fundacion de Ambato
#
#       day_transferred  oil_price store_city store_state store_type  \
# 14256           False      47.24      Quito   Pichincha          D
# 14257           False      47.24      Quito   Pichincha          D
# 14258           False      47.24      Quito   Pichincha          D
# 14259           False      47.24      Quito   Pichincha          D
# 14260           False      47.24      Quito   Pichincha          D
# ...               ...        ...        ...         ...        ...
# 16033           False      47.24      Quito   Pichincha          B
# 16034           False      47.24      Quito   Pichincha          B
# 16035           False      47.24      Quito   Pichincha          B
# 16036           False      47.24      Quito   Pichincha          B
# 16037           False      47.24      Quito   Pichincha          B
#
#        store_cluster
# 14256             13
# 14257             13
# 14258             13
# 14259             13
# 14260             13
# ...              ...
# 16033              6
# 16034              6
# 16035              6
# 16036              6
# 16037              6
#
# [1782 rows x 15 columns]

# %% [markdown]
# ## Encode the string values

# %%
product_groups = train_merged.groupby("family")
product_groups.get_group("DAIRY").head()
# Out:
#           id        date  store_nbr family  sales  onpromotion day_type  \
# 73070  73070  2013-02-11          1  DAIRY  151.0            0  Holiday
# 73103  73103  2013-02-11         10  DAIRY   72.0            0  Holiday
# 73136  73136  2013-02-11         11  DAIRY  218.0            0  Holiday
# 73169  73169  2013-02-11         12  DAIRY  141.0            0  Holiday
# 73202  73202  2013-02-11         13  DAIRY   82.0            0  Holiday
#
#       day_locale day_locale_name day_description day_transferred  oil_price  \
# 73070   National         Ecuador        Carnaval           False      97.01
# 73103   National         Ecuador        Carnaval           False      97.01
# 73136   National         Ecuador        Carnaval           False      97.01
# 73169   National         Ecuador        Carnaval           False      97.01
# 73202   National         Ecuador        Carnaval           False      97.01
#
#       store_city store_state store_type  store_cluster
# 73070      Quito   Pichincha          D             13
# 73103      Quito   Pichincha          C             15
# 73136    Cayambe   Pichincha          B              6
# 73169  Latacunga    Cotopaxi          C             15
# 73202  Latacunga    Cotopaxi          C             15
